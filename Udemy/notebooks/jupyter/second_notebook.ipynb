# %%
import os

# %%
os
# Out:
# <module 'os' (frozen)>

# %%
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_KILLED',
#  'CLD_STOPPED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GenericAlias',
#  'Mapping',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EVTONLY',
#  'O_EXCL',
#  'O_EXLOCK',
#  'O_FSYNC',
#  'O_NDELAY',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NOFOLLOW_ANY',
#  'O_NONBLOCK',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_SHLOCK',
#  'O_SYMLINK',
#  'O_SYNC',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_SPAWN_CLOSE',
#  'POSIX_SPAWN_DUP2',
#  'POSIX_SPAWN_OPEN',
#  'PRIO_DARWIN_BG',
#  'PRIO_DARWIN_NONUI',
# ...

# %%
os.environ
# Out:
# environ{'__CFBundleIdentifier': 'com.apple.Terminal',
#         'TMPDIR': '/var/folders/7c/wj2t8lb975vg15szzxfl5wfm0000gn/T/',
#         'XPC_FLAGS': '0x0',
#         'TERM': 'xterm-color',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.Kb2ViuuS6H/Listeners',
#         'XPC_SERVICE_NAME': '0',
#         'TERM_PROGRAM': 'Apple_Terminal',
#         'TERM_PROGRAM_VERSION': '445.1',
#         'TERM_SESSION_ID': '99A72D5C-ECC5-41BE-9DA0-3AD7CF523307',
#         'SHELL': '/bin/zsh',
#         'HOME': '/Users/vladimirmutaf',
#         'LOGNAME': 'vladimirmutaf',
#         'USER': 'vladimirmutaf',
#         'PATH': '/Users/vladimirmutaf/.local/bin:/Users/vladimirmutaf/.poetry/bin:/Users/vladimirmutaf/.local/bin:/Users/vladimirmutaf/.poetry/bin:/Library/Frameworks/Python.framework/Versions/3.12/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/Library/Frameworks/Python.framework/Versions/3.12/bin',
#         'SHLVL': '1',
#         'PWD': '/Users/vladimirmutaf',
# ...

# %%
print

# %%
os.
